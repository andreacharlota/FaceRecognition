# %% [markdown]
# <a href="https://colab.research.google.com/github/andreacharlota/FaceRecognition/blob/main/FaceRecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
pip install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=1ec96f9908ab87c2ce1bdee12f32477b494ff5e7f63ba8889daade9aa915f3c5
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
import cv2

# %%
import face_recognition

# %% [markdown]
# # **FACE RECOGNITION ON IMAGE**

# %%
from google.colab import files
# upload the image file
uploaded = files.upload()
# upload the haarcascade file
uploaded_haarcascade = files.upload()
# Out:
#      <input type="file" id="files-b5b68f4f-d64a-4a8a-a416-b0795e1034ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5b68f4f-d64a-4a8a-a416-b0795e1034ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread("Joy.jpg")
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_encoding = face_recognition.face_encodings(rgb_img) [0]

# %%
img2 =  cv2.imread("Joy Red Velvet.jpg")
rgb_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img_encoding2 = face_recognition.face_encodings(rgb_img2) [0]

# %%
result = face_recognition.compare_faces ([img_encoding], img_encoding2)
print("Result: ", result)
# Out:
# Result:  [True]

# %%
from google.colab import files
# upload the image file
uploaded = files.upload()
# upload the haarcascade file
uploaded_haarcascade = files.upload()
# Out:
#      <input type="file" id="files-3b7bed7c-2ab5-4766-b621-8bebb41f6962" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b7bed7c-2ab5-4766-b621-8bebb41f6962">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread("Joy.jpg")
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_encoding = face_recognition.face_encodings(rgb_img) [0]

# %%
img2 =  cv2.imread("Lana Del Rey.jpg")
rgb_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img_encoding2 = face_recognition.face_encodings(rgb_img2) [0]

# %%
result = face_recognition.compare_faces ([img_encoding], img_encoding2)
print("Result: ", result)
# Out:
# Result:  [False]

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x900 at 0x7F3349461FF0>
# <PIL.Image.Image image mode=RGB size=1000x1664 at 0x7F3349461BA0>

# %%
import os
# Encode all faces from folder
# Load the dataset images
image_folder = 'image'
image_files = os.listdir(image_folder)

# Create lists to store face encodings & corresponding labels
face_encodings = []
labels = []

# Loop through the images
for image_file in image_files:
    image_path = os.path.join(image_folder, image_file)

    # Load the image
    image = face_recognition.load_image_file(image_path)

    # Find face location
    face_locations = face_recognition.face_locations(image)

    # Encode the faces
    face_encoding = face_recognition.face_encodings(image, face_locations) 

    # Add the face encoding & label to the lists
    face_encodings.append(face_encoding)
    labels.append(image_file)

    print(f"Number of faces encoded: {len(face_encodings)}")
# Out:
# Number of faces encoded: 1
# Number of faces encoded: 2
# Number of faces encoded: 3
# Number of faces encoded: 4
# Number of faces encoded: 5
# Number of faces encoded: 6

# %% [markdown]
# # **FACE RECOGNITION IN REAL-TIME ON WEBCAM**

# %%
import cv2
